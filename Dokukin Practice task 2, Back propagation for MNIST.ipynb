# %% [markdown]
# ## Семинар 2 "Распознавание рукописных цифр"

# %% [markdown]
# ФИО: Докукин Сергей Александрович

# %% [markdown]
# В этом задании мы используем нейронную сеть из предыдущего семинара для распознавания рукописных цифр. Также мы исследуем как влияет выбор нелинейности и предобработка данных на качество классификации.
#
# Чтобы не тратить время на подготовку данных, мы прилагаем готовый код с примером использования для получения обучающей и тестовой выборок. Для запуска скрипта вам понадобится библиотека PyTorch (инструкции по установке можно найти на сайте <a href="http://pytorch.org">pytorch.org</a>)

# %%
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchvision import transforms
import numpy as np
import sys
from layers import Linear, Sigmoid, NLLLoss, NeuralNetwork # Results from Seminar 1
from IPython.display import clear_output
# %matplotlib inline

num_of_epochs = 20

# %%
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.1307,), (0.3081,))
                               ])
train_dataset = MNIST('.', train=True, download=True, transform=transform)
test_dataset = MNIST('.', train=False, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
X, y = next(iter(train_loader))
X = X.numpy()
y = y.numpy()

print(X[0].shape)
# Out:
# (1, 28, 28)

# %%
plt.figure(figsize=(6, 7))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(X[i].reshape(28, 28), cmap=plt.cm.Greys_r)
    plt.title(y[i])
    plt.axis('off')

# %% [markdown]
# ### Часть 1: MNIST
# Обучите полносвязную нейронную сеть с архитектурой 784-100-100-10 и сигмоидой в качестве нелинейности. Какую точность классификации удалось получить? Нарисуйте график сходимости на обучающей и тестовой выборках. В качестве темпа обучения (learning rate) возьмите 0.01

# %%
def train(network, epochs, learning_rate, plot=True,
          verbose=True, loss=None):
    loss = loss or NLLLoss()
    train_loss_epochs = []
    test_loss_epochs = []
    train_accuracy_epochs = []
    test_accuracy_epochs = []
    try:
        for epoch in range(epochs):
            losses = []
            accuracies = []
            for X, y in train_loader:
                X = X.view(X.shape[0], -1).numpy()
                y = y.numpy()
                prediction = network.forward(X)
                loss_batch = loss.forward(prediction, y)
                losses.append(loss_batch)
                dLdx = loss.backward()
                network.backward(dLdx)
                network.step(learning_rate)
                accuracies.append((np.argmax(prediction, 1)==y).mean())
            train_loss_epochs.append(np.mean(losses))
            train_accuracy_epochs.append(np.mean(accuracies))
            losses = []
            accuracies = []    
            for X, y in test_loader:
                X = X.view(X.shape[0], -1).numpy()
                y = y.numpy()
                prediction = network.forward(X)
                loss_batch = loss.forward(prediction, y)
                losses.append(loss_batch)
                accuracies.append((np.argmax(prediction, 1)==y).mean())
            test_loss_epochs.append(np.mean(losses))
            test_accuracy_epochs.append(np.mean(accuracies))
            clear_output(True)
            if verbose:
                sys.stdout.write('\rEpoch {0}... (Train/Test) NLL: {1:.3f}/{2:.3f}\tAccuracy: {3:.3f}/{4:.3f}'.format(
                            epoch, train_loss_epochs[-1], test_loss_epochs[-1],
                            train_accuracy_epochs[-1], test_accuracy_epochs[-1]))
            if plot:
                plt.figure(figsize=(12, 5))
                plt.subplot(1, 2, 1)
                plt.plot(train_loss_epochs, label='Train')
                plt.plot(test_loss_epochs, label='Test')
                plt.xlabel('Epochs', fontsize=16)
                plt.ylabel('Loss', fontsize=16)
                plt.legend(loc=0, fontsize=16)
                plt.grid('on')
                plt.subplot(1, 2, 2)
                plt.plot(train_accuracy_epochs, label='Train accuracy')
                plt.plot(test_accuracy_epochs, label='Test accuracy')
                plt.xlabel('Epochs', fontsize=16)
                plt.ylabel('Accuracy', fontsize=16)
                plt.legend(loc=0, fontsize=16)
                plt.grid('on')
                plt.show()
    except KeyboardInterrupt:
        pass
    return train_loss_epochs, \
           test_loss_epochs, \
           train_accuracy_epochs, \
           test_accuracy_epochs

# %%
network = NeuralNetwork([Linear(784, 100), Sigmoid(),
                         Linear(100, 100), Sigmoid(),
                         Linear(100, 10)])
loss = NLLLoss()

# %%
tr_s, ts_s, tr_ac_s, ts_ac_s = train(network, num_of_epochs, 0.01)
# Out:
# Epoch 19... (Train/Test) NLL: 0.302/0.295	Accuracy: 0.921/0.921

# %% [markdown]
# ### Часть 2: Нелинейности

# %% [markdown]
# Обучите нейронную сеть с другими нелинейностями: ReLU и ELU. Сравните скорости сходимости и качество классификации с различными функциями активации.

# %%
class ReLU:
    def __init__(self):
        pass

    def forward(self, X):
        '''
        Passes objects through this layer.
        X is np.array of size (N, d)
        '''
        self.X = X
        return np.maximum(X, 0)

    def backward(self, dLdy):
        '''
        1. Compute dLdx.
        2. Return dLdx
        '''
        dydX = (self.X >= 0).astype(float)
        return dLdy * dydX

    def step(self, learning_rate):
        pass

# %%
class ELU:
    '''
    ELU(x) = x, x > 0; a*(e^x - 1), x <= 0
    '''
    
    def __init__(self, a=1):
        self.a = a

    def forward(self, X):
        '''
        Passes objects through this layer.
        X is np.array of size (N, d)
        '''
        self.X = X
        return X * (X > 0) + self.a * (np.exp(X) - 1) * (X <= 0)
    
    def backward(self, dLdy):
        '''
        1. Compute dLdx.
        2. Return dLdx
        '''
        X = self.X
        dydX = (X > 0) + self.a * np.exp(X) * (X <= 0)
        return dLdy * dydX

    def step(self, learning_rate):
        pass

# %%
network = NeuralNetwork([Linear(784, 100), ReLU(),
                         Linear(100, 100), ReLU(),
                         Linear(100, 10)])
loss = NLLLoss()
tr_r, ts_r, tr_ac_r, ts_ac_r = train(network, num_of_epochs, 0.01)
# Out:
# Epoch 19... (Train/Test) NLL: 0.036/0.080	Accuracy: 0.990/0.976

# %%
network = NeuralNetwork([Linear(784, 100), ELU(),
                         Linear(100, 100), ELU(),
                         Linear(100, 10)])
loss = NLLLoss()
tr_e, ts_e, tr_ac_e, ts_ac_e = train(network, num_of_epochs, 0.01)
# Out:
# Epoch 19... (Train/Test) NLL: 0.046/0.084	Accuracy: 0.987/0.975

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.title('Loss')
plt.plot(ts_s, label='Sigmoid')
plt.plot(ts_r, label='ReLU')
plt.plot(ts_e, label='ELU')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend(loc=0, fontsize=16)
plt.grid()
plt.subplot(1, 2, 2)
plt.title('Accuracy')
plt.plot(ts_ac_s, label='Sigmoid')
plt.plot(ts_ac_r, label='ReLU')
plt.plot(ts_ac_e, label='ELU')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.legend(loc=0, fontsize=16)
plt.grid()
plt.show()

# %% [markdown]
# ### HW1 (1 балл): Реализовать Tanh

# %%
class Tanh:
    def __init__(self):
        pass

    def forward(self, X):
        '''
        Passes objects through this layer.
        X is np.array of size (N, d)
        '''
        self.expX = np.exp(X)
        self.exp_X = np.exp(-X)
        return (self.expX - self.exp_X) / (self.expX + self.exp_X)

    def backward(self, dLdy):
        '''
        1. Compute dLdx.
        2. Return dLdx
        '''
        self.chX = (self.expX + self.exp_X) / 2
        dydX = 1 / self.chX ** 2
        return dLdy * dydX

    def step(self, learning_rate):
        pass

# %%
network = NeuralNetwork([Linear(784, 100), Tanh(),
                         Linear(100, 100), Tanh(),
                         Linear(100, 10)])
loss = NLLLoss()
tr_t, ts_t, tr_ac_t, ts_ac_t = train(network, num_of_epochs, 0.01)
# Out:
# Epoch 19... (Train/Test) NLL: 0.030/0.079	Accuracy: 0.994/0.975

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.title('Loss')
plt.plot(ts_s, label='Sigmoid')
plt.plot(ts_r, label='ReLU')
plt.plot(ts_e, label='ELU')
plt.plot(ts_t, label='Tanh')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend(loc=0, fontsize=16)
plt.grid()
plt.subplot(1, 2, 2)
plt.title('Accuracy')
plt.plot(ts_ac_s, label='Sigmoid')
plt.plot(ts_ac_r, label='ReLU')
plt.plot(ts_ac_e, label='ELU')
plt.plot(ts_ac_t, label='Tanh')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.legend(loc=0, fontsize=16)
plt.grid()
plt.show()

# %% [markdown]
# ### Часть 3: Анализ ошибок

# %%
wrong_X = []
correct_y = []
predicted_y = []
logits = []
for X, y in test_loader:
    X = X.view(X.shape[0], -1).numpy()
    y = y.numpy()
    prediction = network.forward(X)
    prediction = np.exp(prediction)
    prediction /= prediction.sum(1, keepdims=True)
    for i in range(len(prediction)):
        if np.argmax(prediction[i]) != y[i]:
            wrong_X.append(X[i])
            correct_y.append(y[i])
            predicted_y.append(np.argmax(prediction[i]))
            logits.append(prediction[i][y[i]])
wrong_X = np.row_stack(wrong_X)
correct_y = np.row_stack(correct_y)[:, 0]
predicted_y = np.row_stack(predicted_y)[:, 0]
logits = np.row_stack(logits)[:, 0]

# %%
plt.figure(figsize=(10, 5))
order = np.argsort(logits)
for i in range(21):
    plt.subplot(3, 7, i+1)
    plt.imshow(wrong_X[order[i]].reshape(28, 28), cmap=plt.cm.Greys_r)
    plt.title('{}({})'.format(correct_y[order[i]], predicted_y[order[i]]), fontsize=20)
    plt.axis('off')

# %% [markdown]
# ### Часть 4: Аугментация (HW, 2 балла)
# * Небольшие вращения (-15, 15)
# * Случайные сдвиги
# * Шум
#
# Какой прирост дают эти аугментации вместе и по отдельности

# %%
from skimage.transform import rotate
from scipy.ndimage import interpolation
from skimage.util import random_noise as r_noise

# %%
def train(network, epochs, learning_rate, plot=True,
          verbose=True, loss=None, AugmentFunction=None):
    loss = loss or NLLLoss()
    train_loss_epochs = []
    test_loss_epochs = []
    train_accuracy_epochs = []
    test_accuracy_epochs = []
    try:
        for epoch in range(epochs):
            losses = []
            accuracies = []
            for X, y in train_loader:
                X = X.view(X.shape[0], -1).numpy()
                
                if AugmentFunction is not None:
                    for aug_func in AugmentFunction: 
                        X = aug_func(X)
                
                y = y.numpy()
                prediction = network.forward(X)
                loss_batch = loss.forward(prediction, y)
                losses.append(loss_batch)
                dLdx = loss.backward()
                network.backward(dLdx)
                network.step(learning_rate)
                accuracies.append((np.argmax(prediction, 1)==y).mean())
            train_loss_epochs.append(np.mean(losses))
            train_accuracy_epochs.append(np.mean(accuracies))
            losses = []
            accuracies = []    
            for X, y in test_loader:
                X = X.view(X.shape[0], -1).numpy()
                y = y.numpy()
                prediction = network.forward(X)
                loss_batch = loss.forward(prediction, y)
                losses.append(loss_batch)
                accuracies.append((np.argmax(prediction, 1)==y).mean())
            test_loss_epochs.append(np.mean(losses))
            test_accuracy_epochs.append(np.mean(accuracies))
            clear_output(True)
            if verbose:
                sys.stdout.write('\rEpoch {0}... (Train/Test) NLL: {1:.3f}/{2:.3f}\tAccuracy: {3:.3f}/{4:.3f}'.format(
                            epoch, train_loss_epochs[-1], test_loss_epochs[-1],
                            train_accuracy_epochs[-1], test_accuracy_epochs[-1]))
            if plot:
                plt.figure(figsize=(12, 5))
                plt.subplot(1, 2, 1)
                plt.plot(train_loss_epochs, label='Train')
                plt.plot(test_loss_epochs, label='Test')
                plt.xlabel('Epochs', fontsize=16)
                plt.ylabel('Loss', fontsize=16)
                plt.legend(loc=0, fontsize=16)
                plt.grid('on')
                plt.subplot(1, 2, 2)
                plt.plot(train_accuracy_epochs, label='Train accuracy')
                plt.plot(test_accuracy_epochs, label='Test accuracy')
                plt.xlabel('Epochs', fontsize=16)
                plt.ylabel('Accuracy', fontsize=16)
                plt.legend(loc=0, fontsize=16)
                plt.grid('on')
                plt.show()
    except KeyboardInterrupt:
        pass
    return train_loss_epochs, \
           test_loss_epochs, \
           train_accuracy_epochs, \
           test_accuracy_epochs

# %%
def rot_func(X, rot_angle_max=5):
    angle = np.random.randn() * rot_angle_max
    return rotate(X, angle)

# %%
def tr_func(X, max_x_shift=1, max_y_shift=1):
    x_shift = max_x_shift * np.random.randn()
    y_shift = max_y_shift * np.random.randn()
    return interpolation.shift(X, (x_shift, y_shift), mode='nearest')

# %%
def noise_func(X, mean=0, var=0.01):
    return r_noise(X, mean=mean, var=var)

# %%
def NewNeuralNetwork():
    return NeuralNetwork([Linear(784, 100), Tanh(),
                         Linear(100, 100), Tanh(),
                         Linear(100, 10)])

# %%
X, y = next(iter(train_loader))
X = X.numpy()
y = y.numpy()

print(X[0].shape)
# Out:
# (1, 28, 28)

# %%
print(X[0].shape)
plt.figure(figsize=(6, 7))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(X[i].reshape(28, 28), cmap=plt.cm.Greys_r)
    plt.title(y[i])
    plt.axis('off')
# Out:
# (1, 28, 28)

# %%
print(X[0].shape)
plt.figure(figsize=(6, 7))
for _ in range(10):
    for i in range(25):
        plt.subplot(5, 5, i+1)
        plt.imshow(tr_func(X[i].reshape(28, 28), max_x_shift=3, max_y_shift=3), cmap=plt.cm.Greys_r)
        plt.title(y[i])
        plt.axis('off')
    plt.show()
# Out:
# (1, 28, 28)

# %%
print(X[0].shape)
plt.figure(figsize=(6, 7))
for _ in range(10):
    for i in range(25):
        plt.subplot(5, 5, i+1)
        plt.imshow(rot_func(X[i].reshape(28, 28), rot_angle_max=15), cmap=plt.cm.Greys_r)
        plt.title(y[i])
        plt.axis('off')
    plt.show()
# Out:
# (1, 28, 28)

# %%
network = NewNeuralNetwork()
loss = NLLLoss()
tr_t_rot, ts_t_rot, tr_ac_t_rot, ts_ac_t_rot = train(network, num_of_epochs, 0.01, AugmentFunction=[rot_func,])
# Out:
# Epoch 19... (Train/Test) NLL: 1.906/0.969	Accuracy: 0.304/0.684

# %%
network = NewNeuralNetwork()
loss = NLLLoss()
tr_t_shift, ts_t_shift, tr_ac_t_shift, ts_ac_t_shift = train(network, num_of_epochs, 0.01, AugmentFunction=[tr_func,])
# Out:
# Epoch 19... (Train/Test) NLL: 1.861/0.797	Accuracy: 0.435/0.943

# %%
network = NewNeuralNetwork()
loss = NLLLoss()
tr_t_noise, ts_t_noise, tr_ac_t_noise, ts_ac_t_noise = train(network, num_of_epochs, 0.01, AugmentFunction=[noise_func,])
# Out:
# Epoch 19... (Train/Test) NLL: 0.069/0.118	Accuracy: 0.981/0.963

# %%
network = NewNeuralNetwork()
loss = NLLLoss()
tr_t_rot_shift, ts_t_rot_shift, \
tr_ac_t_rot_shift, ts_ac_t_rot_shift = train(network, num_of_epochs,
                                             0.01, AugmentFunction=[tr_func, rot_func])
# Out:
# Epoch 19... (Train/Test) NLL: 2.180/1.413	Accuracy: 0.209/0.671

# %%
network = NewNeuralNetwork()
loss = NLLLoss()
tr_t_rot_noise, ts_t_rot_noise, \
tr_ac_t_rot_noise, ts_ac_t_rot_noise = train(network, num_of_epochs,
                                             0.01, AugmentFunction=[noise_func, rot_func])
# Out:
# Epoch 19... (Train/Test) NLL: 1.948/1.097	Accuracy: 0.293/0.615

# %%
network = NewNeuralNetwork()
loss = NLLLoss()
tr_t_shift_noise, ts_t_shift_noise, \
tr_ac_t_shift_noise, ts_ac_t_shift_noise = train(network, num_of_epochs,
                                             0.01, AugmentFunction=[noise_func, tr_func])
# Out:
# Epoch 19... (Train/Test) NLL: 1.910/0.833	Accuracy: 0.409/0.906

# %%
network = NewNeuralNetwork()
loss = NLLLoss()
tr_t_shift_rot_noise, ts_t_shift_rot_noise, \
tr_ac_t_shift_rot_noise, ts_ac_t_shift_rot_noise = train(network, num_of_epochs,
                                             0.01, AugmentFunction=[noise_func, tr_func, rot_func])
# Out:
# Epoch 19... (Train/Test) NLL: 2.203/1.434	Accuracy: 0.194/0.537

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.title('Loss')
plt.plot(ts_t, label='Tanh')
plt.plot(ts_t_shift, label='shift')
plt.plot(ts_t_rot, label='rot')
plt.plot(ts_t_noise, label='noise')
plt.plot(ts_t_rot_shift, label='rot_shift')
plt.plot(ts_t_rot_noise, label='rot_noise')
plt.plot(ts_t_shift_noise, label='shift_noise')
plt.plot(ts_t_shift_rot_noise, label='shift_rot_noise')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend(loc=0, fontsize=16)
plt.grid()
plt.subplot(1, 2, 2)
plt.title('Accuracy')
plt.plot(ts_ac_t, label='Tanh')
plt.plot(ts_ac_t_shift, label='shift')
plt.plot(ts_ac_t_rot, label='rot')
plt.plot(ts_ac_t_noise, label='noise')
plt.plot(ts_ac_t_rot_shift, label='rot_shift')
plt.plot(ts_ac_t_rot_noise, label='rot_noise')
plt.plot(ts_ac_t_shift_noise, label='shift_noise')
plt.plot(ts_ac_t_shift_rot_noise, label='shift_rot_noise')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.legend(loc=0, fontsize=16)
plt.grid()
plt.show()

# %% [markdown]
# ### Часть 5: Выводы
# Опишите полученные результаты: как влияют выбор нелинейности и предобработка данных на скорость сходимости и итоговое качество?

# %% [markdown]
# Все нелинейности, кроме сигмы, сработали примерно одинаково.
# Использование аугментаций ухудшает качество работы.
# В теории должно быть наоборот из-за увеличения размера тестовой выборки при аугментировании, но на практике использование аугментаций значительно увеличивает время обучения и 20 эпох уже не хватает.
# Ставить больше эпох становится напряжно из-за времени.
# Также важен выбор параметров, так как при использований малых амплитуд аугментаций быстрее обучается, но пользы от них меньше.
